# %%
import numpy as np
import os
import random
import pandas as pd
from tqdm import tqdm

import cv2
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow.keras
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras import backend as K
from tensorflow.keras.utils import plot_model
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.metrics import Recall, Precision
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")

# %%
image_path = '/kaggle/input/heart-segmentation-images/img'
mask_path= '/kaggle/input/heart-segmentation-mask-images/masks_heart'

# %%
image_list = os.listdir(image_path)

mask_list = [filename for filename in image_list]
print(len(image_list))
print(len(mask_list))
# Out:
# 238
# 238

# %%
for i in range(len(image_list)):
  print(image_list[i],"----",mask_list[i])
# Out:
# CHNCXR_0092_0.png ---- CHNCXR_0092_0.png
# MCUCXR_0017_0.png ---- MCUCXR_0017_0.png
# CHNCXR_0041_0.png ---- CHNCXR_0041_0.png
# CHNCXR_0036_0.png ---- CHNCXR_0036_0.png
# MCUCXR_0020_0.png ---- MCUCXR_0020_0.png
# MCUCXR_0030_0.png ---- MCUCXR_0030_0.png
# MCUCXR_0013_0.png ---- MCUCXR_0013_0.png
# MCUCXR_0354_1.png ---- MCUCXR_0354_1.png
# MCUCXR_0044_0.png ---- MCUCXR_0044_0.png
# CHNCXR_0074_0.png ---- CHNCXR_0074_0.png
# CHNCXR_0013_0.png ---- CHNCXR_0013_0.png
# MCUCXR_0255_1.png ---- MCUCXR_0255_1.png
# MCUCXR_0399_1.png ---- MCUCXR_0399_1.png
# MCUCXR_0027_0.png ---- MCUCXR_0027_0.png
# MCUCXR_0043_0.png ---- MCUCXR_0043_0.png
# MCUCXR_0063_0.png ---- MCUCXR_0063_0.png
# MCUCXR_0048_0.png ---- MCUCXR_0048_0.png
# CHNCXR_0032_0.png ---- CHNCXR_0032_0.png
# CHNCXR_0049_0.png ---- CHNCXR_0049_0.png
# CHNCXR_0068_0.png ---- CHNCXR_0068_0.png
# MCUCXR_0294_1.png ---- MCUCXR_0294_1.png
# CHNCXR_0095_0.png ---- CHNCXR_0095_0.png
# MCUCXR_0266_1.png ---- MCUCXR_0266_1.png
# MCUCXR_0173_1.png ---- MCUCXR_0173_1.png
# CHNCXR_0098_0.png ---- CHNCXR_0098_0.png
# MCUCXR_0313_1.png ---- MCUCXR_0313_1.png
# MCUCXR_0113_1.png ---- MCUCXR_0113_1.png
# CHNCXR_0048_0.png ---- CHNCXR_0048_0.png
# MCUCXR_0144_1.png ---- MCUCXR_0144_1.png
# MCUCXR_0390_1.png ---- MCUCXR_0390_1.png
# MCUCXR_0058_0.png ---- MCUCXR_0058_0.png
# MCUCXR_0228_1.png ---- MCUCXR_0228_1.png
# CHNCXR_0096_0.png ---- CHNCXR_0096_0.png
# MCUCXR_0289_1.png ---- MCUCXR_0289_1.png
# MCUCXR_0049_0.png ---- MCUCXR_0049_0.png
# CHNCXR_0001_0.png ---- CHNCXR_0001_0.png
# CHNCXR_0021_0.png ---- CHNCXR_0021_0.png
# MCUCXR_0006_0.png ---- MCUCXR_0006_0.png
# MCUCXR_0253_1.png ---- MCUCXR_0253_1.png
# MCUCXR_0047_0.png ---- MCUCXR_0047_0.png
# CHNCXR_0004_0.png ---- CHNCXR_0004_0.png
# MCUCXR_0003_0.png ---- MCUCXR_0003_0.png
# MCUCXR_0367_1.png ---- MCUCXR_0367_1.png
# CHNCXR_0090_0.png ---- CHNCXR_0090_0.png
# CHNCXR_0064_0.png ---- CHNCXR_0064_0.png
# CHNCXR_0039_0.png ---- CHNCXR_0039_0.png
# CHNCXR_0071_0.png ---- CHNCXR_0071_0.png
# MCUCXR_0040_0.png ---- MCUCXR_0040_0.png
# CHNCXR_0061_0.png ---- CHNCXR_0061_0.png
# MCUCXR_0041_0.png ---- MCUCXR_0041_0.png
# MCUCXR_0170_1.png ---- MCUCXR_0170_1.png
# CHNCXR_0056_0.png ---- CHNCXR_0056_0.png
# MCUCXR_0001_0.png ---- MCUCXR_0001_0.png
# CHNCXR_0003_0.png ---- CHNCXR_0003_0.png
# MCUCXR_0021_0.png ---- MCUCXR_0021_0.png
# MCUCXR_0056_0.png ---- MCUCXR_0056_0.png
# MCUCXR_0218_1.png ---- MCUCXR_0218_1.png
# MCUCXR_0117_1.png ---- MCUCXR_0117_1.png
# CHNCXR_0069_0.png ---- CHNCXR_0069_0.png
# MCUCXR_0282_1.png ---- MCUCXR_0282_1.png
# MCUCXR_0101_0.png ---- MCUCXR_0101_0.png
# MCUCXR_0102_0.png ---- MCUCXR_0102_0.png
# MCUCXR_0085_0.png ---- MCUCXR_0085_0.png
# CHNCXR_0029_0.png ---- CHNCXR_0029_0.png
# CHNCXR_0067_0.png ---- CHNCXR_0067_0.png
# CHNCXR_0079_0.png ---- CHNCXR_0079_0.png
# MCUCXR_0372_1.png ---- MCUCXR_0372_1.png
# MCUCXR_0024_0.png ---- MCUCXR_0024_0.png
# CHNCXR_0072_0.png ---- CHNCXR_0072_0.png
# CHNCXR_0033_0.png ---- CHNCXR_0033_0.png
# CHNCXR_0100_0.png ---- CHNCXR_0100_0.png
# CHNCXR_0050_0.png ---- CHNCXR_0050_0.png
# MCUCXR_0028_0.png ---- MCUCXR_0028_0.png
# CHNCXR_0009_0.png ---- CHNCXR_0009_0.png
# CHNCXR_0040_0.png ---- CHNCXR_0040_0.png
# MCUCXR_0064_0.png ---- MCUCXR_0064_0.png
# MCUCXR_0251_1.png ---- MCUCXR_0251_1.png
# MCUCXR_0060_0.png ---- MCUCXR_0060_0.png
# CHNCXR_0002_0.png ---- CHNCXR_0002_0.png
# MCUCXR_0081_0.png ---- MCUCXR_0081_0.png
# MCUCXR_0082_0.png ---- MCUCXR_0082_0.png
# CHNCXR_0006_0.png ---- CHNCXR_0006_0.png
# CHNCXR_0080_0.png ---- CHNCXR_0080_0.png
# MCUCXR_0108_1.png ---- MCUCXR_0108_1.png
# CHNCXR_0054_0.png ---- CHNCXR_0054_0.png
# MCUCXR_0079_0.png ---- MCUCXR_0079_0.png

# %%
def getData(shape):
    im_array = []
    mask_array = []
    shape = (shape, shape)
    # shape = image_size
    for i in tqdm(image_list): 
      # im.shape = (shape, shape, 1)
      im = cv2.imread(os.path.join(image_path,i))
      im = cv2.resize(im, shape)[:, :, 0]
      im = cv2.equalizeHist(im)
      # mask.shape = (shape, shape, 1)
      mask = cv2.imread(os.path.join(mask_path, i))
      mask = cv2.resize(mask, shape)[:, :, 0]

   
      
      im_array.append(im)
      mask_array.append(mask)

      

    return im_array, mask_array

# %%
dim = 512
image_arr, mask_arr = getData(dim)
# Out:
# 100%|██████████| 238/238 [00:33<00:00,  7.03it/s]

# %%
image_arr = np.array(image_arr).reshape(len(image_arr), dim, dim, 1)
mask_arr = np.array(mask_arr).reshape(len(mask_arr), dim, dim, 1)

# %%
def scale_image(image):
    image_min = np.min(image)
    image_max = np.max(image)
    scaled_image = (image - image_min) / (image_max - image_min)
    contrast_adjusted_image = (scaled_image - 0.5) * 1.2 + 0.5  
    return np.clip(contrast_adjusted_image, 0.0, 1.0)

fig, axs = plt.subplots(nrows=3, ncols=2, figsize=(9, 13))

for i in range(3):
    axs[i, 0].imshow(np.squeeze(image_arr[i]), vmin=0, vmax=255, cmap='gray')
    axs[i, 0].set_ylabel('Image')
    axs[i, 0].set_title('CXR')
    axs[i, 0].axis('off')

    axs[i, 1].imshow(np.squeeze(mask_arr[i]), vmin=0, vmax=255, cmap='gray')
    axs[i, 1].set_title('Mask')
    axs[i, 1].axis('off')

plt.tight_layout()
plt.show()

# %%
X_train, X_val, Y_train, Y_val = train_test_split((image_arr - 127.0) / 127.0, 
                                                  (mask_arr > 127).astype(np.float32), 
                                                  test_size = 0.1, 
                                                  random_state = 42 )
print(X_train.shape, X_val.shape, Y_train.shape, Y_val.shape)
# Out:
# (214, 512, 512, 1) (24, 512, 512, 1) (214, 512, 512, 1) (24, 512, 512, 1)

# %% [markdown]
# **Implementation 1**

# %%
def iou(y_true, y_pred):
    def f(y_true, y_pred):
        intersection = (y_true * y_pred).sum()
        union = y_true.sum() + y_pred.sum() - intersection
        x = (intersection + 1e-15) / (union + 1e-15)
        x = x.astype(np.float32)
        return x
    return tf.numpy_function(f, [y_true, y_pred], tf.float32)

smooth = 1e-15
def dice_coef(y_true, y_pred):
    y_true = tf.keras.layers.Flatten()(y_true)
    y_pred = tf.keras.layers.Flatten()(y_pred)
    intersection = tf.reduce_sum(y_true * y_pred)
    return (2. * intersection + smooth) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth)

def dice_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

# %%
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, MaxPool2D, Conv2DTranspose, Concatenate, Input
from tensorflow.keras.models import Model

def conv_block(input, num_filters):
    x = Conv2D(num_filters, 3, padding="same")(input)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = Conv2D(num_filters, 3, padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    return x

def encoder_block(input, num_filters):
    x = conv_block(input, num_filters)
    p = MaxPool2D((2, 2))(x)
    return x, p

def decoder_block(input, skip_features, num_filters):
    x = Conv2DTranspose(num_filters, (2, 2), strides=2, padding="same")(input)
    x = Concatenate()([x, skip_features])
    x = conv_block(x, num_filters)
    return x

def build_unet(input_shape):
    inputs = Input(input_shape)

    s1, p1 = encoder_block(inputs, 64)
    s2, p2 = encoder_block(p1, 128)
    s3, p3 = encoder_block(p2, 256)
    s4, p4 = encoder_block(p3, 512)

    b1 = conv_block(p4, 1024)

    d1 = decoder_block(b1, s4, 512)
    d2 = decoder_block(d1, s3, 256)
    d3 = decoder_block(d2, s2, 128)
    d4 = decoder_block(d3, s1, 64)

    outputs = Conv2D(1, 1, padding="same", activation="sigmoid")(d4)

    model = Model(inputs, outputs, name="U-Net")
    return model

# %%
model = build_unet(input_shape=(512,512,1))
model.compile(optimizer=Adam(lr=2e-4), loss=dice_loss,
                  metrics=[dice_coef, iou, Recall(), Precision(),'binary_accuracy','accuracy'])
model.summary()
# Out:
# Model: "U-Net"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 512, 512, 1  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 512, 512, 64  640         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 512, 512, 64  256        ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 512, 512, 64  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 512, 512, 64  36928       ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 512, 512, 64  256        ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 512, 512, 64  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 256, 256, 64  0           ['activation_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 256, 256, 12  73856       ['max_pooling2d[0][0]']
#                                 8)
#
#  batch_normalization_2 (BatchNo  (None, 256, 256, 12  512        ['conv2d_2[0][0]']
#  rmalization)                   8)
#
#  activation_2 (Activation)      (None, 256, 256, 12  0           ['batch_normalization_2[0][0]']
#                                 8)
#
#  conv2d_3 (Conv2D)              (None, 256, 256, 12  147584      ['activation_2[0][0]']
#                                 8)
#
#  batch_normalization_3 (BatchNo  (None, 256, 256, 12  512        ['conv2d_3[0][0]']
#  rmalization)                   8)
#
#  activation_3 (Activation)      (None, 256, 256, 12  0           ['batch_normalization_3[0][0]']
#                                 8)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 128, 128, 12  0          ['activation_3[0][0]']
#                                 8)
#
#  conv2d_4 (Conv2D)              (None, 128, 128, 25  295168      ['max_pooling2d_1[0][0]']
#                                 6)
#
#  batch_normalization_4 (BatchNo  (None, 128, 128, 25  1024       ['conv2d_4[0][0]']
#  rmalization)                   6)
#
#  activation_4 (Activation)      (None, 128, 128, 25  0           ['batch_normalization_4[0][0]']
#                                 6)
#
#  conv2d_5 (Conv2D)              (None, 128, 128, 25  590080      ['activation_4[0][0]']
#                                 6)
#
#  batch_normalization_5 (BatchNo  (None, 128, 128, 25  1024       ['conv2d_5[0][0]']
#  rmalization)                   6)
#
#  activation_5 (Activation)      (None, 128, 128, 25  0           ['batch_normalization_5[0][0]']
#                                 6)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 64, 64, 256)  0          ['activation_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 64, 64, 512)  1180160     ['max_pooling2d_2[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 64, 64, 512)  2048       ['conv2d_6[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 64, 64, 512)  0           ['batch_normalization_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 64, 64, 512)  2359808     ['activation_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 64, 64, 512)  2048       ['conv2d_7[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 64, 64, 512)  0           ['batch_normalization_7[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 32, 32, 512)  0          ['activation_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 32, 32, 1024  4719616     ['max_pooling2d_3[0][0]']
#                                 )
#
#  batch_normalization_8 (BatchNo  (None, 32, 32, 1024  4096       ['conv2d_8[0][0]']
#  rmalization)                   )
#
#  activation_8 (Activation)      (None, 32, 32, 1024  0           ['batch_normalization_8[0][0]']
#                                 )
#
#  conv2d_9 (Conv2D)              (None, 32, 32, 1024  9438208     ['activation_8[0][0]']
#                                 )
#
#  batch_normalization_9 (BatchNo  (None, 32, 32, 1024  4096       ['conv2d_9[0][0]']
#  rmalization)                   )
#
#  activation_9 (Activation)      (None, 32, 32, 1024  0           ['batch_normalization_9[0][0]']
#                                 )
#
#  conv2d_transpose (Conv2DTransp  (None, 64, 64, 512)  2097664    ['activation_9[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 64, 64, 1024  0           ['conv2d_transpose[0][0]',
#                                 )                                 'activation_7[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 64, 64, 512)  4719104     ['concatenate[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_10[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 64, 64, 512)  0           ['batch_normalization_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 64, 64, 512)  2359808     ['activation_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 64, 64, 512)  0           ['batch_normalization_11[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 128, 128, 25  524544     ['activation_11[0][0]']
#  spose)                         6)
#
#  concatenate_1 (Concatenate)    (None, 128, 128, 51  0           ['conv2d_transpose_1[0][0]',
#                                 2)                                'activation_5[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 128, 128, 25  1179904     ['concatenate_1[0][0]']
#                                 6)
#
#  batch_normalization_12 (BatchN  (None, 128, 128, 25  1024       ['conv2d_12[0][0]']
#  ormalization)                  6)
#
#  activation_12 (Activation)     (None, 128, 128, 25  0           ['batch_normalization_12[0][0]']
#                                 6)
#
#  conv2d_13 (Conv2D)             (None, 128, 128, 25  590080      ['activation_12[0][0]']
#                                 6)
#
#  batch_normalization_13 (BatchN  (None, 128, 128, 25  1024       ['conv2d_13[0][0]']
#  ormalization)                  6)
#
#  activation_13 (Activation)     (None, 128, 128, 25  0           ['batch_normalization_13[0][0]']
#                                 6)
#
#  conv2d_transpose_2 (Conv2DTran  (None, 256, 256, 12  131200     ['activation_13[0][0]']
#  spose)                         8)
#
#  concatenate_2 (Concatenate)    (None, 256, 256, 25  0           ['conv2d_transpose_2[0][0]',
#                                 6)                                'activation_3[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 256, 256, 12  295040      ['concatenate_2[0][0]']
#                                 8)
#
#  batch_normalization_14 (BatchN  (None, 256, 256, 12  512        ['conv2d_14[0][0]']
#  ormalization)                  8)
#
#  activation_14 (Activation)     (None, 256, 256, 12  0           ['batch_normalization_14[0][0]']
#                                 8)
#
#  conv2d_15 (Conv2D)             (None, 256, 256, 12  147584      ['activation_14[0][0]']
#                                 8)
#
#  batch_normalization_15 (BatchN  (None, 256, 256, 12  512        ['conv2d_15[0][0]']
#  ormalization)                  8)
#
#  activation_15 (Activation)     (None, 256, 256, 12  0           ['batch_normalization_15[0][0]']
#                                 8)
#
#  conv2d_transpose_3 (Conv2DTran  (None, 512, 512, 64  32832      ['activation_15[0][0]']
#  spose)                         )
#
#  concatenate_3 (Concatenate)    (None, 512, 512, 12  0           ['conv2d_transpose_3[0][0]',
#                                 8)                                'activation_1[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 512, 512, 64  73792       ['concatenate_3[0][0]']
#                                 )
#
#  batch_normalization_16 (BatchN  (None, 512, 512, 64  256        ['conv2d_16[0][0]']
#  ormalization)                  )
#
#  activation_16 (Activation)     (None, 512, 512, 64  0           ['batch_normalization_16[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 512, 512, 64  36928       ['activation_16[0][0]']
#                                 )
#
#  batch_normalization_17 (BatchN  (None, 512, 512, 64  256        ['conv2d_17[0][0]']
#  ormalization)                  )
#
#  activation_17 (Activation)     (None, 512, 512, 64  0           ['batch_normalization_17[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 512, 512, 1)  65          ['activation_17[0][0]']
#
# ==================================================================================================
# Total params: 31,054,145
# Trainable params: 31,042,369
# Non-trainable params: 11,776
# __________________________________________________________________________________________________

# %%
weight_path="{}_weights.best.hdf5".format('cxr_heart')

checkpoint = ModelCheckpoint(weight_path, monitor='val_loss', verbose=1, 
                             save_best_only=True, mode='min', save_weights_only = True)

reduceLROnPlat = ReduceLROnPlateau(monitor='val_loss', factor=0.5, 
                                   patience=3, 
                                   verbose=1, mode='min', min_delta=0.0001, cooldown=2, min_lr=1e-6)
early = EarlyStopping(monitor="val_loss", 
                      mode="min", 
                      patience=15) 
callbacks_list = [checkpoint, early, reduceLROnPlat]

# %%
h = model.fit(X_train, Y_train, 
                validation_data=(X_val, Y_val), 
                batch_size=4, epochs=50,
                callbacks= callbacks_list)
# Out:
# Epoch 1/50
# 54/54 [==============================] - ETA: 0s - loss: 0.5629 - dice_coef: 0.4391 - iou: 0.2910 - recall: 0.7280 - precision: 0.3284 - binary_accuracy: 0.8558 - accuracy: 0.8558
# Epoch 1: val_loss improved from inf to 0.94931, saving model to cxr_heart_weights.best.hdf5
# 54/54 [==============================] - 61s 564ms/step - loss: 0.5629 - dice_coef: 0.4391 - iou: 0.2910 - recall: 0.7280 - precision: 0.3284 - binary_accuracy: 0.8558 - accuracy: 0.8558 - val_loss: 0.9493 - val_dice_coef: 0.0507 - val_iou: 0.0263 - val_recall: 0.0449 - val_precision: 0.1018 - val_binary_accuracy: 0.9033 - val_accuracy: 0.9033 - lr: 0.0010
# Epoch 2/50
# 54/54 [==============================] - ETA: 0s - loss: 0.4024 - dice_coef: 0.5988 - iou: 0.4328 - recall: 0.7230 - precision: 0.5472 - binary_accuracy: 0.9283 - accuracy: 0.9283
# Epoch 2: val_loss improved from 0.94931 to 0.78089, saving model to cxr_heart_weights.best.hdf5
# 54/54 [==============================] - 24s
# 54/54 [==============================] - 23s 433ms/step - loss: 0.2645 - dice_coef: 0.7342 - iou: 0.5887 - recall: 0.7636 - precision: 0.7012 - binary_accuracy: 0.9540 - accuracy: 0.9540 - val_loss: 0.8393 - val_dice_coef: 0.1607 - val_iou: 0.0892 - val_recall: 0.0841 - val_precision: 0.9734 - val_binary_accuracy: 0.9343 - val_accuracy: 0.9343 - lr: 5.0000e-04
# Epoch 19/50
# 54/54 [==============================] - ETA: 0s - loss: 0.2615 - dice_coef: 0.7347 - iou: 0.5911 - recall: 0.7583 - precision: 0.7184 - binary_accuracy: 0.9559 - accuracy: 0.9559
# Epoch 19: val_loss improved from 0.26760 to 0.26177, saving model to cxr_heart_weights.best.hdf5
# 54/54 [==============================] - 24s 442ms/step - loss: 0.2615 - dice_coef: 0.7347 - iou: 0.5911 - recall: 0.7583 - precision: 0.7184 - binary_accuracy: 0.9559 - accuracy: 0.9559 - val_loss: 0.2618 - val_dice_coef: 0.7382 - val_iou: 0.5898 - val_recall: 0.7750 - val_precision: 0.7073 - val_binary_accuracy: 0.9609 - val_accuracy: 0.9609 - lr: 5.0000e-04
# Epoch 20/50
# 54/54 [==============================] - ETA: 0s - loss: 0.2532 - dice_coef: 0.7472 - iou: 0.6061 - recall: 0.7766 - precision: 0.7141 - binary_accuracy: 0.9562 - accuracy: 0.9562
# Epoch 20: val_loss did not improve from 0.26177
# 54/54 [==============================] - 23s 433ms/step - loss: 0.2532 - dice_coef: 0.7472 - iou: 0.6061 - recall: 0.7766 - precision: 0.7141 - binary_accuracy: 0.9562 - accuracy: 0.9562 - val_loss: 0.6220 - val_dice_coef: 0.3780 - val_iou: 0.2422 - val_recall: 0.2482 - val_precision: 0.8275 - val_binary_accuracy: 0.9425 - val_accuracy: 0.9425 - lr: 5.0000e-04
# Epoch 21/50
# 54/54 [==============================] - ETA: 0s - loss: 0.2551 - dice_coef: 0.7467 - iou: 0.6042 - recall: 0.7749 - precision: 0.7163 - binary_accuracy: 0.9564 - accuracy: 0.9564
# Epoch 21: val_loss did not improve from 0.26177
# 54/54 [==============================] - 23s 433ms/step - loss: 0.2551 - dice_coef: 0.7467 - iou: 0.6042 - recall: 0.7749 - precision: 0.7163 - binary_accuracy: 0.9564 - accuracy: 0.9564 - val_loss: 0.2704 - val_dice_coef: 0.7296 - val_iou: 0.5816 - val_recall: 0.7937 - val_precision: 0.6737 - val_binary_accuracy: 0.9577 - val_accuracy: 0.9577 - lr: 5.0000e-04
# Epoch 22/50
# 54/54 [==============================] - ETA: 0s - loss: 0.2451 - dice_coef: 0.7545 - iou: 0.6130 - recall: 0.7857 - precision: 0.7222 - binary_accuracy: 0.9577 - accuracy: 0.9577
# Epoch 22: val_loss did not improve from 0.26177
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 54/54 [==============================] - 23s 433ms/step - loss: 0.2451 - dice_coef: 0.7545 - iou: 0.6130 - recall: 0.7857 - precision: 0.7222 - binary_accuracy: 0.9577 - accuracy: 0.9577 - val_loss: 0.2724 - val_dice_coef: 0.7276 - val_iou: 0.5797 - val_recall: 0.8150 - val_precision: 0.6583 - val_binary_accuracy: 0.9565 - val_accuracy: 0.9565 - lr: 5.0000e-04
# Epoch 23/50
# 54/54 [==============================] - ETA: 0s - loss: 0.2377 - dice_coef: 0.7607 - iou: 0.6225 - recall: 0.7885 - precision: 0.7349 - binary_accuracy: 0.9594 - accuracy: 0.9594
# Epoch 23: val_loss did not improve from 0.26177
# 54/54 [==============================] - 23s 433ms/step - loss: 0.2377 - dice_coef: 0.7607 - iou: 0.6225 - recall: 0.7885 - precision: 0.7349 - binary_accuracy: 0.9594 - accuracy: 0.9594 - val_loss: 0.2933 - val_dice_coef: 0.7067 - val_iou: 0.5542 - val_recall: 0.8952 - val_precision: 0.5805 - val_binary_accuracy: 0.9462 - val_accuracy: 0.9462 - lr: 2.5000e-04
# Epoch 24/50
# 54/54 [==============================] - ETA: 0s - loss: 0.2324 - dice_coef: 0.7689 - iou: 0.6352 - recall: 0.8001 - precision: 0.7352 - binary_accuracy: 0.9600 - accuracy: 0.9600
# Epoch 24: val_loss did not improve from 0.26177
# 54/54 [==============================] - 23s 433ms/step - loss: 0.2324 - dice_coef: 0.7689 - iou: 0.6352 - recall: 0.8001 - precision: 0.7352 - binary_accuracy: 0.9600 - accuracy: 0.9600 - val_loss: 0.3384 - val_dice_coef: 0.6616 - val_iou: 0.5010 - val_recall: 0.9082 - val_precision: 0.5185 - val_binary_accuracy: 0.9331 - val_accuracy: 0.9331 - lr: 2.5000e-04
# Epoch 25/50
# 54/54 [==============================] - ETA: 0s - loss: 0.2312 - dice_coef: 0.7689 - iou: 0.6309 - recall: 0.7904 - precision: 0.7425 - binary_accuracy: 0.9604 - accuracy: 0.9604
# Epoch 25: val_loss improved from 0.26177 to 0.24242, saving model to cxr_heart_weights.best.hdf5
# 54/54 [==============================] - 24s 441ms/step - loss: 0.2312 - dice_coef: 0.7689 - iou: 0.6309 - recall: 0.7904 - precision: 0.7425 - binary_accuracy: 0.9604 - accuracy: 0.9604 - val_loss: 0.2424 - val_dice_coef: 0.7576 - val_iou: 0.6176 - val_recall: 0.8678 - val_precision: 0.6656 - val_binary_accuracy: 0.9593 - val_accuracy: 0.9593 - lr: 2.5000e-04
# Epoch 26/50
# 54/54 [==============================] - ETA: 0s - loss: 0.2260 - dice_coef: 0.7738 - iou: 0.6383 - recall: 0.7939 - precision: 0.7490 - binary_accuracy: 0.9613 - accuracy: 0.9613
# Epoch 26: val_loss improved from 0.24242 to 0.24061, saving model to cxr_heart_weights.best.hdf5
# 54/54 [==============================] - 24s 447ms/step - loss: 0.2260 - dice_coef: 0.7738 - iou: 0.6383 - recall: 0.7939 - precision: 0.7490 - binary_accuracy: 0.9613 - accuracy: 0.9613 - val_loss: 0.2406 - val_dice_coef: 0.7594 - val_iou: 0.6203 - val_recall: 0.8635 - val_precision: 0.6712 - val_binary_accuracy: 0.9599 - val_accuracy: 0.9599 - lr: 2.5000e-04
# Epoch 27/50
# 54/54 [==============================] - ETA: 0s - loss: 0.2279 - dice_coef: 0.7724 - iou: 0.6380 - recall: 0.7994 - precision: 0.7386 - binary_accuracy: 0.9604 - accuracy: 0.9604
# Epoch 27: val_loss improved from 0.24061 to 0.23834, saving model to cxr_heart_weights.best.hdf5
# 54/54 [==============================] - 24s 447ms/step - loss: 0.2279 - dice_coef: 0.7724 - iou: 0.6380 - recall: 0.7994 - precision: 0.7386 - binary_accuracy: 0.9604 - accuracy: 0.9604 - val_loss: 0.2383 - val_dice_coef: 0.7617 - val_iou: 0.6216 - val_recall: 0.8108 - val_precision: 0.7146 - val_binary_accuracy: 0.9633 - val_accuracy: 0.9633 - lr: 2.5000e-04
# Epoch 28/50
# 54/54 [==============================] - ETA: 0s - loss: 0.2223 - dice_coef: 0.7769 - iou: 0.6433 - recall: 0.7983 - precision: 0.7557 - binary_accuracy: 0.9623 - accuracy: 0.9623
# Epoch 28: val_loss did not improve from 0.23834
# 54/54 [==============================] - 23s 433ms/step - loss: 0.2223 - dice_coef: 0.7769 - iou: 0.6433 - recall: 0.7983 - precision: 0.7557 - binary_accuracy: 0.9623 - accuracy: 0.9623 - val_loss: 0.2623 - val_dice_coef: 0.7377 - val_iou: 0.5912 - val_recall: 0.7481 - val_precision: 0.7293 - val_binary_accuracy: 0.9621 - val_accuracy: 0.9621 - lr: 2.5000e-04
# Epoch 29/50
# 54/54 [==============================] - ETA: 0s - loss: 0.2257 - dice_coef: 0.7752 - iou: 0.6414 - recall: 0.7966 - precision: 0.7493 - binary_accuracy: 0.9615 - accuracy: 0.9615
# Epoch 29: val_loss did not improve from 0.23834
# 54/54 [==============================] - 24s 441ms/step - loss: 0.2257 - dice_coef: 0.7752 - iou: 0.6414 - recall: 0.7966 - precision: 0.7493 - binary_accuracy: 0.9615 - accuracy: 0.9615 - val_loss: 0.2746 - val_dice_coef: 0.7254 - val_iou: 0.5769 - val_recall: 0.6828 - val_precision: 0.7732 - val_binary_accuracy: 0.9630 - val_accuracy: 0.9630 - lr: 2.5000e-04
# Epoch 30/50
# 54/54 [==============================] - ETA: 0s - loss: 0.2228 - dice_coef: 0.7755 - iou: 0.6413 - recall: 0.7910 - precision: 0.7570 - binary_accuracy: 0.9621 - accuracy: 0.9621
# Epoch 30: val_loss did not improve from 0.23834
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 54/54 [==============================] - 23s 433ms/step - loss: 0.2228 - dice_coef: 0.7755 - iou: 0.6413 - recall: 0.7910 - precision: 0.7570 - binary_accuracy: 0.9621 - accuracy: 0.9621 - val_loss: 0.3091 - val_dice_coef: 0.6909 - val_iou: 0.5352 - val_recall: 0.8967 - val_precision: 0.5607 - val_binary_accuracy: 0.9423 - val_accuracy: 0.9423 - lr: 2.5000e-04
# Epoch 31/50
# 54/54 [==============================] - ETA: 0s - loss: 0.2108 - dice_coef: 0.7900 - iou: 0.6620 - recall: 0.8101 - precision: 0.7611 - binary_accuracy: 0.9636 - accuracy: 0.9636
# Epoch 31: val_loss did not improve from 0.23834
# 54/54 [==============================] - 23s 433ms/step - loss: 0.2108 - dice_coef: 0.7900 - iou: 0.6620 - recall: 0.8101 - precision: 0.7611 - binary_accuracy: 0.9636 - accuracy: 0.9636 - val_loss: 0.2390 - val_dice_coef: 0.7610 - val_iou: 0.6205 - val_recall: 0.7848 - val_precision: 0.7392 - val_binary_accuracy: 0.9648 - val_accuracy: 0.9648 - lr: 1.2500e-04
# Epoch 32/50
# 54/54 [==============================] - ETA: 0s - loss: 0.2066 - dice_coef: 0.7947 - iou: 0.6690 - recall: 0.8061 - precision: 0.7757 - binary_accuracy: 0.9650 - accuracy: 0.9650
# Epoch 32: val_loss did not improve from 0.23834
# 54/54 [==============================] - 24s 441ms/step - loss: 0.2066 - dice_coef: 0.7947 - iou: 0.6690 - recall: 0.8061 - precision: 0.7757 - binary_accuracy: 0.9650 - accuracy: 0.9650 - val_loss: 0.2468 - val_dice_coef: 0.7532 - val_iou: 0.6118 - val_recall: 0.7817 - val_precision: 0.7274 - val_binary_accuracy: 0.9634 - val_accuracy: 0.9634 - lr: 1.2500e-04
# Epoch 33/50
# 54/54 [==============================] - ETA: 0s - loss: 0.2036 - dice_coef: 0.7949 - iou: 0.6669 - recall: 0.8106 - precision: 0.7808 - binary_accuracy: 0.9659 - accuracy: 0.9659
# Epoch 33: val_loss did not improve from 0.23834
# 54/54 [==============================] - 24s 440ms/step - loss: 0.2036 - dice_coef: 0.7949 - iou: 0.6669 - recall: 0.8106 - precision: 0.7808 - binary_accuracy: 0.9659 - accuracy: 0.9659 - val_loss: 0.2435 - val_dice_coef: 0.7565 - val_iou: 0.6149 - val_recall: 0.8062 - val_precision: 0.7125 - val_binary_accuracy: 0.9628 - val_accuracy: 0.9628 - lr: 1.2500e-04
# Epoch 34/50
# 54/54 [==============================] - ETA: 0s - loss: 0.2004 - dice_coef: 0.8007 - iou: 0.6750 - recall: 0.8131 - precision: 0.7816 - binary_accuracy: 0.9661 - accuracy: 0.9661
# Epoch 34: val_loss improved from 0.23834 to 0.23547, saving model to cxr_heart_weights.best.hdf5
# 54/54 [==============================] - 24s 440ms/step - loss: 0.2004 - dice_coef: 0.8007 - iou: 0.6750 - recall: 0.8131 - precision: 0.7816 - binary_accuracy: 0.9661 - accuracy: 0.9661 - val_loss: 0.2355 - val_dice_coef: 0.7645 - val_iou: 0.6266 - val_recall: 0.8139 - val_precision: 0.7162 - val_binary_accuracy: 0.9636 - val_accuracy: 0.9636 - lr: 1.2500e-04
# Epoch 35/50
# 54/54 [==============================] - ETA: 0s - loss: 0.1973 - dice_coef: 0.8030 - iou: 0.6787 - recall: 0.8123 - precision: 0.7903 - binary_accuracy: 0.9670 - accuracy: 0.9670
# Epoch 35: val_loss did not improve from 0.23547
# 54/54 [==============================] - 24s 441ms/step - loss: 0.1973 - dice_coef: 0.8030 - iou: 0.6787 - recall: 0.8123 - precision: 0.7903 - binary_accuracy: 0.9670 - accuracy: 0.9670 - val_loss: 0.2393 - val_dice_coef: 0.7607 - val_iou: 0.6214 - val_recall: 0.8787 - val_precision: 0.6671 - val_binary_accuracy: 0.9599 - val_accuracy: 0.9599 - lr: 1.2500e-04
# Epoch 36/50
# 54/54 [==============================] - ETA: 0s - loss: 0.1983 - dice_coef: 0.8017 - iou: 0.6758 - recall: 0.8158 - precision: 0.7841 - binary_accuracy: 0.9665 - accuracy: 0.9665
# Epoch 36: val_loss improved from 0.23547 to 0.23020, saving model to cxr_heart_weights.best.hdf5
# 54/54 [==============================] - 24s 440ms/step - loss: 0.1983 - dice_coef: 0.8017 - iou: 0.6758 - recall: 0.8158 - precision: 0.7841 - binary_accuracy: 0.9665 - accuracy: 0.9665 - val_loss: 0.2302 - val_dice_coef: 0.7698 - val_iou: 0.6333 - val_recall: 0.7829 - val_precision: 0.7502 - val_binary_accuracy: 0.9658 - val_accuracy: 0.9658 - lr: 1.2500e-04
# Epoch 37/50
# 54/54 [==============================] - ETA: 0s - loss: 0.1931 - dice_coef: 0.8060 - iou: 0.6816 - recall: 0.8193 - precision: 0.7911 - binary_accuracy: 0.9675 - accuracy: 0.9675
# Epoch 37: val_loss did not improve from 0.23020
# 54/54 [==============================] - 23s 433ms/step - loss: 0.1931 - dice_coef: 0.8060 - iou: 0.6816 - recall: 0.8193 - precision: 0.7911 - binary_accuracy: 0.9675 - accuracy: 0.9675 - val_loss: 0.2331 - val_dice_coef: 0.7669 - val_iou: 0.6298 - val_recall: 0.8412 - val_precision: 0.7022 - val_binary_accuracy: 0.9631 - val_accuracy: 0.9631 - lr: 1.2500e-04
# Epoch 38/50
# 54/54 [==============================] - ETA: 0s - loss: 0.1878 - dice_coef: 0.8131 - iou: 0.6909 - recall: 0.8245 - precision: 0.7983 - binary_accuracy: 0.9686 - accuracy: 0.9686
# Epoch 38: val_loss did not improve from 0.23020
# 54/54 [==============================] - 23s 433ms/step - loss: 0.1878 - dice_coef: 0.8131 - iou: 0.6909 - recall: 0.8245 - precision: 0.7983 - binary_accuracy: 0.9686 - accuracy: 0.9686 - val_loss: 0.2481 - val_dice_coef: 0.7519 - val_iou: 0.6104 - val_recall: 0.8145 - val_precision: 0.6959 - val_binary_accuracy: 0.9612 - val_accuracy: 0.9612 - lr: 1.2500e-04
# Epoch 39/50
# 54/54 [==============================] - ETA: 0s - loss: 0.1861 - dice_coef: 0.8126 - iou: 0.6920 - recall: 0.8228 - precision: 0.8035 - binary_accuracy: 0.9690 - accuracy: 0.9690
# Epoch 39: val_loss did not improve from 0.23020
#
# Epoch 39: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 54/54 [==============================] - 23s 433ms/step - loss: 0.1861 - dice_coef: 0.8126 - iou: 0.6920 - recall: 0.8228 - precision: 0.8035 - binary_accuracy: 0.9690 - accuracy: 0.9690 - val_loss: 0.2816 - val_dice_coef: 0.7184 - val_iou: 0.5706 - val_recall: 0.6880 - val_precision: 0.7562 - val_binary_accuracy: 0.9618 - val_accuracy: 0.9618 - lr: 1.2500e-04
# Epoch 40/50
# 54/54 [==============================] - ETA: 0s - loss: 0.1799 - dice_coef: 0.8209 - iou: 0.7012 - recall: 0.8280 - precision: 0.8102 - binary_accuracy: 0.9700 - accuracy: 0.9700
# Epoch 40: val_loss did not improve from 0.23020
# 54/54 [==============================] - 24s 441ms/step - loss: 0.1799 - dice_coef: 0.8209 - iou: 0.7012 - recall: 0.8280 - precision: 0.8102 - binary_accuracy: 0.9700 - accuracy: 0.9700 - val_loss: 0.2436 - val_dice_coef: 0.7564 - val_iou: 0.6171 - val_recall: 0.7902 - val_precision: 0.7238 - val_binary_accuracy: 0.9634 - val_accuracy: 0.9634 - lr: 6.2500e-05
# Epoch 41/50
# 54/54 [==============================] - ETA: 0s - loss: 0.1732 - dice_coef: 0.8261 - iou: 0.7095 - recall: 0.8333 - precision: 0.8187 - binary_accuracy: 0.9712 - accuracy: 0.9712
# Epoch 41: val_loss did not improve from 0.23020
# 54/54 [==============================] - 24s 441ms/step - loss: 0.1732 - dice_coef: 0.8261 - iou: 0.7095 - recall: 0.8333 - precision: 0.8187 - binary_accuracy: 0.9712 - accuracy: 0.9712 - val_loss: 0.2593 - val_dice_coef: 0.7407 - val_iou: 0.5969 - val_recall: 0.7602 - val_precision: 0.7194 - val_binary_accuracy: 0.9616 - val_accuracy: 0.9616 - lr: 6.2500e-05
# Epoch 42/50
# 54/54 [==============================] - ETA: 0s - loss: 0.1765 - dice_coef: 0.8228 - iou: 0.7035 - recall: 0.8257 - precision: 0.8211 - binary_accuracy: 0.9710 - accuracy: 0.9710
# Epoch 42: val_loss did not improve from 0.23020
# 54/54 [==============================] - 23s 433ms/step - loss: 0.1765 - dice_coef: 0.8228 - iou: 0.7035 - recall: 0.8257 - precision: 0.8211 - binary_accuracy: 0.9710 - accuracy: 0.9710 - val_loss: 0.2598 - val_dice_coef: 0.7402 - val_iou: 0.5963 - val_recall: 0.7267 - val_precision: 0.7519 - val_binary_accuracy: 0.9633 - val_accuracy: 0.9633 - lr: 6.2500e-05
# Epoch 43/50
# 54/54 [==============================] - ETA: 0s - loss: 0.1687 - dice_coef: 0.8305 - iou: 0.7165 - recall: 0.8342 - precision: 0.8263 - binary_accuracy: 0.9721 - accuracy: 0.9721
# Epoch 43: val_loss did not improve from 0.23020
#
# Epoch 43: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 54/54 [==============================] - 23s 433ms/step - loss: 0.1687 - dice_coef: 0.8305 - iou: 0.7165 - recall: 0.8342 - precision: 0.8263 - binary_accuracy: 0.9721 - accuracy: 0.9721 - val_loss: 0.2365 - val_dice_coef: 0.7635 - val_iou: 0.6261 - val_recall: 0.8434 - val_precision: 0.6940 - val_binary_accuracy: 0.9622 - val_accuracy: 0.9622 - lr: 6.2500e-05
# Epoch 44/50
# 54/54 [==============================] - ETA: 0s - loss: 0.1636 - dice_coef: 0.8375 - iou: 0.7257 - recall: 0.8305 - precision: 0.8363 - binary_accuracy: 0.9728 - accuracy: 0.9728
# Epoch 44: val_loss did not improve from 0.23020
# 54/54 [==============================] - 23s 433ms/step - loss: 0.1636 - dice_coef: 0.8375 - iou: 0.7257 - recall: 0.8305 - precision: 0.8363 - binary_accuracy: 0.9728 - accuracy: 0.9728 - val_loss: 0.2460 - val_dice_coef: 0.7540 - val_iou: 0.6129 - val_recall: 0.8399 - val_precision: 0.6820 - val_binary_accuracy: 0.9605 - val_accuracy: 0.9605 - lr: 3.1250e-05
# Epoch 45/50
# 54/54 [==============================] - ETA: 0s - loss: 0.1649 - dice_coef: 0.8351 - iou: 0.7217 - recall: 0.8335 - precision: 0.8320 - binary_accuracy: 0.9726 - accuracy: 0.9726
# Epoch 45: val_loss did not improve from 0.23020
# 54/54 [==============================] - 23s 434ms/step - loss: 0.1649 - dice_coef: 0.8351 - iou: 0.7217 - recall: 0.8335 - precision: 0.8320 - binary_accuracy: 0.9726 - accuracy: 0.9726 - val_loss: 0.2429 - val_dice_coef: 0.7571 - val_iou: 0.6172 - val_recall: 0.8210 - val_precision: 0.6977 - val_binary_accuracy: 0.9617 - val_accuracy: 0.9617 - lr: 3.1250e-05
# Epoch 46/50
# 54/54 [==============================] - ETA: 0s - loss: 0.1608 - dice_coef: 0.8391 - iou: 0.7283 - recall: 0.8416 - precision: 0.8338 - binary_accuracy: 0.9733 - accuracy: 0.9733
# Epoch 46: val_loss did not improve from 0.23020
# 54/54 [==============================] - 23s 433ms/step - loss: 0.1608 - dice_coef: 0.8391 - iou: 0.7283 - recall: 0.8416 - precision: 0.8338 - binary_accuracy: 0.9733 - accuracy: 0.9733 - val_loss: 0.2559 - val_dice_coef: 0.7441 - val_iou: 0.6010 - val_recall: 0.7822 - val_precision: 0.7059 - val_binary_accuracy: 0.9611 - val_accuracy: 0.9611 - lr: 3.1250e-05
# Epoch 47/50
# 54/54 [==============================] - ETA: 0s - loss: 0.1622 - dice_coef: 0.8388 - iou: 0.7283 - recall: 0.8355 - precision: 0.8422 - binary_accuracy: 0.9737 - accuracy: 0.9737
# Epoch 47: val_loss did not improve from 0.23020
#
# Epoch 47: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 54/54 [==============================] - 23s 433ms/step - loss: 0.1622 - dice_coef: 0.8388 - iou: 0.7283 - recall: 0.8355 - precision: 0.8422 - binary_accuracy: 0.9737 - accuracy: 0.9737 - val_loss: 0.2599 - val_dice_coef: 0.7401 - val_iou: 0.5964 - val_recall: 0.8047 - val_precision: 0.6832 - val_binary_accuracy: 0.9593 - val_accuracy: 0.9593 - lr: 3.1250e-05
# Epoch 48/50
# 54/54 [==============================] - ETA: 0s - loss: 0.1613 - dice_coef: 0.8372 - iou: 0.7265 - recall: 0.8399 - precision: 0.8372 - binary_accuracy: 0.9735 - accuracy: 0.9735
# Epoch 48: val_loss did not improve from 0.23020
# 54/54 [==============================] - 23s 434ms/step - loss: 0.1613 - dice_coef: 0.8372 - iou: 0.7265 - recall: 0.8399 - precision: 0.8372 - binary_accuracy: 0.9735 - accuracy: 0.9735 - val_loss: 0.2513 - val_dice_coef: 0.7487 - val_iou: 0.6078 - val_recall: 0.8063 - val_precision: 0.6947 - val_binary_accuracy: 0.9608 - val_accuracy: 0.9608 - lr: 1.5625e-05
# Epoch 49/50
# 54/54 [==============================] - ETA: 0s - loss: 0.1575 - dice_coef: 0.8423 - iou: 0.7327 - recall: 0.8400 - precision: 0.8423 - binary_accuracy: 0.9740 - accuracy: 0.9740
# Epoch 49: val_loss did not improve from 0.23020
# 54/54 [==============================] - 23s 434ms/step - loss: 0.1575 - dice_coef: 0.8423 - iou: 0.7327 - recall: 0.8400 - precision: 0.8423 - binary_accuracy: 0.9740 - accuracy: 0.9740 - val_loss: 0.2568 - val_dice_coef: 0.7432 - val_iou: 0.6015 - val_recall: 0.7784 - val_precision: 0.7092 - val_binary_accuracy: 0.9613 - val_accuracy: 0.9613 - lr: 1.5625e-05
# Epoch 50/50
# 54/54 [==============================] - ETA: 0s - loss: 0.1592 - dice_coef: 0.8417 - iou: 0.7315 - recall: 0.8386 - precision: 0.8434 - binary_accuracy: 0.9740 - accuracy: 0.9740
# Epoch 50: val_loss did not improve from 0.23020
# 54/54 [==============================] - 23s 433ms/step - loss: 0.1592 - dice_coef: 0.8417 - iou: 0.7315 - recall: 0.8386 - precision: 0.8434 - binary_accuracy: 0.9740 - accuracy: 0.9740 - val_loss: 0.2529 - val_dice_coef: 0.7471 - val_iou: 0.6054 - val_recall: 0.7901 - val_precision: 0.7062 - val_binary_accuracy: 0.9615 - val_accuracy: 0.9615 - lr: 1.5625e-05

# %%
print(h.history.keys())
# Out:
# dict_keys(['loss', 'dice_coef', 'iou', 'recall', 'precision', 'binary_accuracy', 'accuracy', 'val_loss', 'val_dice_coef', 'val_iou', 'val_recall', 'val_precision', 'val_binary_accuracy', 'val_accuracy', 'lr'])

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))

# Plot loss and validation loss
ax1.plot(h.history['loss'], '-', label='Loss')
ax1.plot(h.history['val_loss'], '-', label='Validation Loss')
ax1.legend()

# Plot dice coefficient and validation dice coefficient
ax2.plot(h.history['accuracy'], '-', label='Accuracy')
ax2.plot(h.history['val_accuracy'], '-', label='Validation Accuracy')
ax2.legend()

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))

# Plot training loss
ax1.plot(h.history['dice_coef'], '-', label='Dice Coefficient')
ax1.plot(h.history['iou'], '-', label='IOU')
ax1.legend()

# Plot dice coefficient and precision
ax2.plot(h.history['dice_coef'], '-', label='Dice Coefficient')
ax2.plot(h.history['precision'], '-', label='Precision')
ax2.legend()

# %%
def get_test(X_shape, n_samples = 5):
    im_array = []
    shape = (X_shape, X_shape)
    test_files = random.choices(list(os.listdir("/kaggle/input/sample/heart images sample")), k=n_samples)
    for i in tqdm(test_files):
        im = cv2.imread(os.path.join("/kaggle/input/sample/heart images sample", i))
        im = cv2.resize(im, shape)[:, :, 0]
        im = cv2.equalizeHist(im)
        im_array.append(im)
    return im_array

# %%
dim, n_samples = 512, 5
X_test = get_test(dim, n_samples = n_samples)
X_test = np.array(X_test).reshape(len(X_test), dim, dim, 1)
X_testNorm = (X_test - 127.0) / 127.0
# Out:
# 100%|██████████| 5/5 [00:00<00:00, 87.23it/s]

# %%
model.load_weights('/kaggle/working/cxr_heart_weights.best.hdf5')
model.summary()
# Out:
# Model: "U-Net"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 512, 512, 1  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 512, 512, 64  640         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 512, 512, 64  256        ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 512, 512, 64  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 512, 512, 64  36928       ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 512, 512, 64  256        ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 512, 512, 64  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 256, 256, 64  0           ['activation_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 256, 256, 12  73856       ['max_pooling2d[0][0]']
#                                 8)
#
#  batch_normalization_2 (BatchNo  (None, 256, 256, 12  512        ['conv2d_2[0][0]']
#  rmalization)                   8)
#
#  activation_2 (Activation)      (None, 256, 256, 12  0           ['batch_normalization_2[0][0]']
#                                 8)
#
#  conv2d_3 (Conv2D)              (None, 256, 256, 12  147584      ['activation_2[0][0]']
#                                 8)
#
#  batch_normalization_3 (BatchNo  (None, 256, 256, 12  512        ['conv2d_3[0][0]']
#  rmalization)                   8)
#
#  activation_3 (Activation)      (None, 256, 256, 12  0           ['batch_normalization_3[0][0]']
#                                 8)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 128, 128, 12  0          ['activation_3[0][0]']
#                                 8)
#
#  conv2d_4 (Conv2D)              (None, 128, 128, 25  295168      ['max_pooling2d_1[0][0]']
#                                 6)
#
#  batch_normalization_4 (BatchNo  (None, 128, 128, 25  1024       ['conv2d_4[0][0]']
#  rmalization)                   6)
#
#  activation_4 (Activation)      (None, 128, 128, 25  0           ['batch_normalization_4[0][0]']
#                                 6)
#
#  conv2d_5 (Conv2D)              (None, 128, 128, 25  590080      ['activation_4[0][0]']
#                                 6)
#
#  batch_normalization_5 (BatchNo  (None, 128, 128, 25  1024       ['conv2d_5[0][0]']
#  rmalization)                   6)
#
#  activation_5 (Activation)      (None, 128, 128, 25  0           ['batch_normalization_5[0][0]']
#                                 6)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 64, 64, 256)  0          ['activation_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 64, 64, 512)  1180160     ['max_pooling2d_2[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 64, 64, 512)  2048       ['conv2d_6[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 64, 64, 512)  0           ['batch_normalization_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 64, 64, 512)  2359808     ['activation_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 64, 64, 512)  2048       ['conv2d_7[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 64, 64, 512)  0           ['batch_normalization_7[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 32, 32, 512)  0          ['activation_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 32, 32, 1024  4719616     ['max_pooling2d_3[0][0]']
#                                 )
#
#  batch_normalization_8 (BatchNo  (None, 32, 32, 1024  4096       ['conv2d_8[0][0]']
#  rmalization)                   )
#
#  activation_8 (Activation)      (None, 32, 32, 1024  0           ['batch_normalization_8[0][0]']
#                                 )
#
#  conv2d_9 (Conv2D)              (None, 32, 32, 1024  9438208     ['activation_8[0][0]']
#                                 )
#
#  batch_normalization_9 (BatchNo  (None, 32, 32, 1024  4096       ['conv2d_9[0][0]']
#  rmalization)                   )
#
#  activation_9 (Activation)      (None, 32, 32, 1024  0           ['batch_normalization_9[0][0]']
#                                 )
#
#  conv2d_transpose (Conv2DTransp  (None, 64, 64, 512)  2097664    ['activation_9[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 64, 64, 1024  0           ['conv2d_transpose[0][0]',
#                                 )                                 'activation_7[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 64, 64, 512)  4719104     ['concatenate[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_10[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 64, 64, 512)  0           ['batch_normalization_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 64, 64, 512)  2359808     ['activation_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 64, 64, 512)  0           ['batch_normalization_11[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 128, 128, 25  524544     ['activation_11[0][0]']
#  spose)                         6)
#
#  concatenate_1 (Concatenate)    (None, 128, 128, 51  0           ['conv2d_transpose_1[0][0]',
#                                 2)                                'activation_5[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 128, 128, 25  1179904     ['concatenate_1[0][0]']
#                                 6)
#
#  batch_normalization_12 (BatchN  (None, 128, 128, 25  1024       ['conv2d_12[0][0]']
#  ormalization)                  6)
#
#  activation_12 (Activation)     (None, 128, 128, 25  0           ['batch_normalization_12[0][0]']
#                                 6)
#
#  conv2d_13 (Conv2D)             (None, 128, 128, 25  590080      ['activation_12[0][0]']
#                                 6)
#
#  batch_normalization_13 (BatchN  (None, 128, 128, 25  1024       ['conv2d_13[0][0]']
#  ormalization)                  6)
#
#  activation_13 (Activation)     (None, 128, 128, 25  0           ['batch_normalization_13[0][0]']
#                                 6)
#
#  conv2d_transpose_2 (Conv2DTran  (None, 256, 256, 12  131200     ['activation_13[0][0]']
#  spose)                         8)
#
#  concatenate_2 (Concatenate)    (None, 256, 256, 25  0           ['conv2d_transpose_2[0][0]',
#                                 6)                                'activation_3[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 256, 256, 12  295040      ['concatenate_2[0][0]']
#                                 8)
#
#  batch_normalization_14 (BatchN  (None, 256, 256, 12  512        ['conv2d_14[0][0]']
#  ormalization)                  8)
#
#  activation_14 (Activation)     (None, 256, 256, 12  0           ['batch_normalization_14[0][0]']
#                                 8)
#
#  conv2d_15 (Conv2D)             (None, 256, 256, 12  147584      ['activation_14[0][0]']
#                                 8)
#
#  batch_normalization_15 (BatchN  (None, 256, 256, 12  512        ['conv2d_15[0][0]']
#  ormalization)                  8)
#
#  activation_15 (Activation)     (None, 256, 256, 12  0           ['batch_normalization_15[0][0]']
#                                 8)
#
#  conv2d_transpose_3 (Conv2DTran  (None, 512, 512, 64  32832      ['activation_15[0][0]']
#  spose)                         )
#
#  concatenate_3 (Concatenate)    (None, 512, 512, 12  0           ['conv2d_transpose_3[0][0]',
#                                 8)                                'activation_1[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 512, 512, 64  73792       ['concatenate_3[0][0]']
#                                 )
#
#  batch_normalization_16 (BatchN  (None, 512, 512, 64  256        ['conv2d_16[0][0]']
#  ormalization)                  )
#
#  activation_16 (Activation)     (None, 512, 512, 64  0           ['batch_normalization_16[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 512, 512, 64  36928       ['activation_16[0][0]']
#                                 )
#
#  batch_normalization_17 (BatchN  (None, 512, 512, 64  256        ['conv2d_17[0][0]']
#  ormalization)                  )
#
#  activation_17 (Activation)     (None, 512, 512, 64  0           ['batch_normalization_17[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 512, 512, 1)  65          ['activation_17[0][0]']
#
# ==================================================================================================
# Total params: 31,054,145
# Trainable params: 31,042,369
# Non-trainable params: 11,776
# __________________________________________________________________________________________________

# %%
preds = model.predict(X_testNorm)
fig, axs = plt.subplots(nrows=5, ncols=2, figsize=(20, 20))

axs[0, 0].imshow(np.squeeze(X_testNorm[0]), cmap='gray')
axs[0, 0].set_title('GT')

axs[0, 1].imshow(np.squeeze(preds[0]), cmap='gray')
axs[0, 1].set_title('predicted mask')

axs[1, 0].imshow(np.squeeze(X_testNorm[1]), cmap='gray')
axs[1, 0].set_title('GT')

axs[1, 1].imshow(np.squeeze(preds[1]), cmap='gray')
axs[1, 1].set_title('predicted mask')

axs[2, 0].imshow(np.squeeze(X_testNorm[2]), cmap='gray')
axs[2, 0].set_title('GT')

axs[2, 1].imshow(np.squeeze(preds[2]), cmap='gray')
axs[2, 1].set_title('predicted mask')

axs[3, 0].imshow(np.squeeze(X_testNorm[3]), cmap='gray')
axs[3, 0].set_title('GT')

axs[3, 1].imshow(np.squeeze(preds[3]), cmap='gray')
axs[3, 1].set_title('predicted mask')

axs[4, 0].imshow(np.squeeze(X_testNorm[4]), cmap='gray')
axs[4, 0].set_title('GT')

axs[4, 1].imshow(np.squeeze(preds[4]), cmap='gray')
axs[4, 1].set_title('predicted mask')
# Out:
# 1/1 [==============================] - 6s 6s/step
# Text(0.5, 1.0, 'predicted mask')
